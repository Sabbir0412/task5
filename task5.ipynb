# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Sabbir Ahmed\\Downloads\\heart.csv')

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
df.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# ...

# %%
sns.displot(df['thalach'],bins=25,kde=True,color='green')
plt.xlabel("age")
plt.show()

# %%
df.cp.value_counts().plot(kind='bar',color=['yellow','red','blue','black'])
plt.title("CHEST PAIN VS COUNT")
# Out:
# Text(0.5, 1.0, 'CHEST PAIN VS COUNT')

# %%
pd.crosstab(df.sex,df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df.target.value_counts().plot(kind='bar',color=['yellow','green'])
plt.title("Heart disease values ")
plt.xlabel("Heart diseases =1   NO Heart diseases=0")
plt.ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')

# %%
df.hist(bins=50,grid=False,figsize=(20,15));

# %%
df.target.value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title("Heart Diseases values")
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %%
df.cp.value_counts().plot(kind='bar',color=['green','yellow','blue','pink'])
plt.title('cheast pain type')
plt.xlabel('Types')
plt.ylabel('Amount')
plt.show()

# %%
df.sex.value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
pd.crosstab(df.sex,df.cp).plot(kind='bar',figsize=(10,5),color=['blue','green','red','yellow'])
plt.title("type of chest pain vs sex")
plt.xlabel("1=Male, 0=Female")
# Out:
# Text(0.5, 0, '1=Male, 0=Female')

# %%
df.sex.value_counts().plot(kind='pie',colors=['red','blue'],autopct='%1.1f%%')
plt.title("Ratio of male and female")
plt.show()

# %%
df.hist(bins=100,grid=True,figsize=(20,15));

# %%
sns.countplot(x='sex',hue='target',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.displot(df['age'],bins=30,kde=True)
plt.xlabel("age")
plt.show()
